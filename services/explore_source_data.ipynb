# %%
import pandas as pd
import numpy as np
import random
df = pd.read_csv('../data/customer_support_tickets.csv')

# %%
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# 1  Peripheral compatibility
# 2           Network problem
# 3            Account access
# 4                 Data loss
#
#                                   Ticket Description  \
# 0  I'm having an issue with the {product_purchase...
# 1  I'm having an issue with the {product_purchase...
# 2  I'm facing a problem with my {product_purchase...
# 3  I'm having an issue with the {product_purchase...
# 4  I'm having an issue with the {product_purchase...
#
#                Ticket Status                                     Resolution  \
# 0  Pending Customer Response                                            NaN
# 1  Pending Customer Response                                            NaN
# 2                     Closed   Case maybe show recently my computer follow.
# 3                     Closed  Try capital clearly never color toward story.
# 4                     Closed                    West decision evidence bit.
#
#   Ticket Priority Ticket Channel  First Response Time   Time to Resolution  \
# 0        Critical   Social media  2023-06-01 12:15:36                  NaN
# 1        Critical           Chat  2023-06-01 16:45:38                  NaN
# 2             Low   Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3             Low   Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4             Low          Email  2023-06-01 00:12:42  2023-06-01 19:53:42
#
#    Customer Satisfaction Rating
# 0                           NaN
# 1                           NaN
# 2                           3.0
# 3                           3.0
# 4                           1.0

# %%
def random_values(df_length, values):
    result = []
    for i in range(0, df_length):
        random.shuffle(values)
        result.append(values[np.random.randint(1,len(values))])
        random.shuffle(values)
    return result

# %%
# approximate value
tokens_per_word = 0.75
df['Tokens Used'] = (df['Ticket Description'].str.count(' ') + 1) * tokens_per_word

# %%
df['Conversation Experience Score'] = random_values(len(df), [i for i in range(1,100)])

# %%
df['Sentiment'] = random_values(len(df), ['neutral', 'negative', 'positive'])

# %%
# Generating a random number of words and picking random indexes of the list to use as tags
df['Tags'] = random_values(len(df), ["complaint", "refund", "warehouse", "brand", "bundling", "BOPIS", "BORIS", "cart", "payment", "loyalty", "EGC", "PGC", "POS", "upsell"])

# %%
df['AutoQA Results'] = random_values(len(df), ['Poor', 'Average', 'Good', 'Great'])

# %%
df['Integration Type Used'] = random_values(len(df), ['Shopify', 'Recharge', 'Klavyio', 'Clutch', 'Adyen', 'Paypal', 'CRM', 'Salesforce'])

# %%
df['Action Taken'] = random_values(len(df), ['Cancel Order', 'Update Address', 'Refund', 'Cancel Item', 'Return', 'None'])

# %%
df['Action Result'] = random_values(len(df), ['successful', 'In progress', 'Failed'])

# %%
df['Knowledge Source'] = random_values(len(df), ['website content', 'product catalogues', 'google sheets', 'google docs', 'confluence'])

# %%
df['Ticket Channel'] = random_values(len(df), ['phonecall', 'whatsapp', 'facebook dm', 'live chat', 'email'])

# %%
df["Response Types"] = random_values(len(df), ['internal note', 'live response'])

# %%
df['User Feedback'] = random_values(len(df), ['positive', 'negative'])

# %%
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# 1  Peripheral compatibility
# 2           Network problem
# 3            Account access
# 4                 Data loss
#
#                                   Ticket Description  ... Tokens Used  \
# 0  I'm having an issue with the {product_purchase...  ...       30.00
# 1  I'm having an issue with the {product_purchase...  ...       30.75
# 2  I'm facing a problem with my {product_purchase...  ...       30.75
# 3  I'm having an issue with the {product_purchase...  ...       30.00
# 4  I'm having an issue with the {product_purchase...  ...       40.50
#
#   Sentiment      Tags AutoQA Results Integration Type Used  Action Taken  \
# 0  negative       EGC           Poor                Clutch   Cancel Item
# 1  negative       PGC           Good              Recharge   Cancel Item
# 2  positive     brand          Great                Paypal  Cancel Order
# 3  positive  bundling        Average            Salesforce        Refund
# 4  positive    refund          Great                 Adyen  Cancel Order
#
#    Action Result    Knowledge Source  Response Types User Feedback
# 0         Failed  product catalogues   live response      positive
# 1     successful       google sheets   internal note      positive
# 2     successful         google docs   internal note      positive
# 3    In progress  product catalogues   live response      positive
# 4         Failed       google sheets   internal note      negative
#
# [5 rows x 28 columns]
